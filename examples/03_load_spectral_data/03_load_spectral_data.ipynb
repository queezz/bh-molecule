# %%
from bh_molecule.instruments.vis133m import Vis133M
from bh_molecule import use_dark
use_dark()

# %% [markdown]
# ## Prep data

# %%
FITS = './data/example.fits'
wavecal_csv = './data/133mVis_wavcal.csv'
s26 = Vis133M(FITS,wavecal_csv)
s26.set_scale(0.0001837)
s26.set_dark(frame=49, channel=43)
s26.set_baseline_zero(True)
s26.set_time_linspace(0, 10)

# %% [markdown]
# ## Pixel range C-F map
# - C: channel
# - F: frame (time)

# %%
s26.plot_pixel_range(456,642,log_scale=True,vmin=5e-3,vmax=10,cmap='gist_gray')
# Out:
# <Axes: xlabel='time (s)', ylabel='channel'>

# %% [markdown]
# ## Band map C-F

# %%
s26.plot_band_map((433.9, 435),log_scale=True,vmin=5e-3,vmax=10,cmap='gist_gray')
# Out:
# <Axes: xlabel='time (s)', ylabel='channel'>

# %% [markdown]
# ## Channel stack

# %%
s26.plot_channel_stack(30,log_scale=True,vmin=0.002,cmap='gist_gray')
# Out:
# <Axes: xlabel='time (s)', ylabel='wavelength (nm)'>

# %%
# Only for mkdocs, you don't need this in your own code
from IPython.display import HTML
import plotly.io as pio

def show_plotly(fig, include_js="cdn"):
    """Return an HTML chunk MkDocs/nbconvert will render."""
    return HTML(pio.to_html(fig, include_plotlyjs=include_js, full_html=False))

# %% [markdown]
# ## Interactive spectrum

# %%
fig = s26.plot_spectrum_plotly(31, 30,theme='dark')
show_plotly(fig) # only for mkdocs, you don't need this in your own code
# fig.show() # for local use
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="91733263-a8a4-48c3-a796-71e225281630" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("91733263-a8a4-48c3-a796-71e225281630")) {                    Plotly.newPlot(                        "91733263-a8a4-48c3-a796-71e225281630",                        [{"hovertemplate":"\u03bb = %{x:.3f} nm\u003cbr\u003eI = %{y:.6g}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"shape":"linear"},"mode":"lines","name":"f=31, ch=30","x":{"dtype":"f8","bdata":"Y7ml1RDtekAdyeU\u002fJO16QOlDF9Q37XpAtr5IaEvtekBGlPYGX+16QBMPKJty7XpApOTVOYbtekBwXwfOme16QDzaOGKt7XpAza\u002fmAMHtekDDZKpg1O16QFQ6WP\u002fn7XpA9nr3x\\u002fTH\u002fB6QM5THXIz8HpAms5OBkfwekBmSYCaWvB6QPceLjlu8HpA7dPxmIHwekB+qZ83lfB6QCHqPgCp8HpAF58CYLzwekCndLD+z\u002fB6QHTv4ZLj8HpABcWPMffwekDRP8HFCvF6QJ268lke8XpAWMoyxDHxekD6CtKMRfF6QMaFAyFZ8XpAgZVDi2zxekBNEHUfgPF6QN7lIr6T8XpAqmBUUqfxekA7NgLxuvF6QAexM4XO8XpA1CtlGeLxekBlARO49fF6QDF8REwJ8npA\u002ffZ14BzyekCOzCN\u002fMPJ6QFpHVRNE8npAFVeVfVfyekDh0cYRa\u002fJ6QIQSZtp+8npAPiKmRJLyekAKndfYpfJ6QJtyhXe58npAZ+22C83yekD4wmSq4PJ6QMU9lj708npAu\u002fJZngfzekAijnVxG\u002fN6QO4IpwUv83pAqBjnb0LzekB1kxgEVvN6QEEOSphp83pA0uP3Nn3zekCeXinLkPN6QC8012mk83pA+64I\u002frfzekDHKTqSy\u002fN6QFj\u002f5zDf83pAJXoZxfLzekDx9EpZBvR6QILK+PcZ9HpAeH+8Vy30ekAIVWr2QPR6QKuVCb9U9HpAZaVJKWj0ekAyIHu9e\u002fR6QP6arFGP9HpAj3Ba8KL0ekBb64uEtvR6QCdmvRjK9HpA4nX9gt30ekCFtpxL8fR6QBWMSuoE9XpAC0EOShj1ekCcFrzoK\u002